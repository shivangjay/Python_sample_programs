# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot

# %%
stock=pd.read_csv('C:\\Users\\Dell\\Desktop\\Jupyter practice\\Python basic\\Assets\\stock1nse.csv')
stock.head()
# Out:
#     SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 50  16,283.95  16,324.70  16,172.60      16,478.10  16,201.80
# 1      GRASIM   1,290.00   1,331.80   1,286.05       1,309.10   1,325.60
# 2  APOLLOHOSP   3,620.50   3,715.00   3,595.50       3,670.05   3,700.00
# 3  ASIANPAINT   2,665.00   2,736.00   2,652.00       2,686.80   2,707.00
# 4    DIVISLAB   3,475.00   3,542.80   3,461.70       3,507.20   3,529.40
#
#    CHNG \n  %CHNG \n  VOLUME \n(shares)              VALUE    52W H \n  \
# 0  -276.30     -1.68          189680523  183,879,230,146.46  18,604.45
# 1    16.50      1.26            1145407    1,506,851,632.92   1,929.80
# 2    29.95      0.82             624657    2,296,926,254.70   5,935.40
# 3    20.20      0.75            1592920    4,317,068,067.20   3,590.00
# 4    22.20      0.63             376643    1,318,265,565.72   5,425.10
#
#     52W L \n  365 D % CHNG \n -  30 D % CHNG \n 09-May-2022
# ...

# %%
stock.columns=['Symbol','Open','High','Low','Prev','LTP','Chng','Chng%','Vol','Value','52W H','52W L','1y chng','1m chng']
stock.head()
# Out:
#        Symbol       Open       High        Low       Prev        LTP    Chng  \
# 0    NIFTY 50  16,283.95  16,324.70  16,172.60  16,478.10  16,201.80 -276.30
# 1      GRASIM   1,290.00   1,331.80   1,286.05   1,309.10   1,325.60   16.50
# 2  APOLLOHOSP   3,620.50   3,715.00   3,595.50   3,670.05   3,700.00   29.95
# 3  ASIANPAINT   2,665.00   2,736.00   2,652.00   2,686.80   2,707.00   20.20
# 4    DIVISLAB   3,475.00   3,542.80   3,461.70   3,507.20   3,529.40   22.20
#
#    Chng%        Vol               Value      52W H      52W L  1y chng  \
# 0  -1.68  189680523  183,879,230,146.46  18,604.45  15,450.90     2.95
# 1   1.26    1145407    1,506,851,632.92   1,929.80   1,286.05   -11.12
# 2   0.82     624657    2,296,926,254.70   5,935.40   3,141.75    11.27
# 3   0.75    1592920    4,317,068,067.20   3,590.00   2,599.35    -8.20
# 4   0.63     376643    1,318,265,565.72   5,425.10   3,365.55   -19.31
#
#    1m chng
# 0     0.21
# 1   -13.60
# 2     0.57
# 3   -11.29
# 4   -17.83

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Symbol   51 non-null     object
#  1   Open     51 non-null     object
#  2   High     51 non-null     object
#  3   Low      51 non-null     object
#  4   Prev     51 non-null     object
#  5   LTP      51 non-null     object
#  6   Chng     51 non-null     float64
#  7   Chng%    51 non-null     float64
#  8   Vol      51 non-null     int64
#  9   Value    51 non-null     object
#  10  52W H    51 non-null     object
#  11  52W L    51 non-null     object
#  12  1y chng  51 non-null     float64
#  13  1m chng  51 non-null     float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 5.7+ KB

# %%
stock['Symbol'=stock.astype('str')
# stock['LTP']=stock['LTP'].str.replace(',','')
# stock['LTP']=stock['LTP'].str.extract('(\d+)', expand=False)
# stock['LTP']=stock['LTP'].astype(float)

# %%
stock.head()
# Out:
#           Symbol          Open          High           Low          Prev  \
# 0    b'NIFTY 50'  b'16,283.95'  b'16,324.70'  b'16,172.60'  b'16,478.10'
# 1      b'GRASIM'   b'1,290.00'   b'1,331.80'   b'1,286.05'   b'1,309.10'
# 2  b'APOLLOHOSP'   b'3,620.50'   b'3,715.00'   b'3,595.50'   b'3,670.05'
# 3  b'ASIANPAINT'   b'2,665.00'   b'2,736.00'   b'2,652.00'   b'2,686.80'
# 4    b'DIVISLAB'   b'3,475.00'   b'3,542.80'   b'3,461.70'   b'3,507.20'
#
#             LTP       Chng     Chng%           Vol                  Value  \
# 0  b'16,201.80'  b'-276.3'  b'-1.68'  b'189680523'  b'183,879,230,146.46'
# 1   b'1,325.60'    b'16.5'   b'1.26'    b'1145407'    b'1,506,851,632.92'
# 2   b'3,700.00'   b'29.95'   b'0.82'     b'624657'    b'2,296,926,254.70'
# 3   b'2,707.00'    b'20.2'   b'0.75'    b'1592920'    b'4,317,068,067.20'
# 4   b'3,529.40'    b'22.2'   b'0.63'     b'376643'    b'1,318,265,565.72'
#
#           52W H         52W L    1y chng    1m chng
# ...

# %%
stock['LTP'].plot(label='LTP',figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-91f7bf3e7c9c> in <module>
# ----> 1 stock['LTP'].plot(label='LTP',figsize=(15,7))
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     267     def generate(self):
# ...
